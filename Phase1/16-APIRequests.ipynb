# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"21696256953","type":"CreateEvent","actor":{"id":49275095,"login":"ursabot","display_login":"ursabot","gravatar_id":"","url":"https://api.github.com/users/ursabot","avatar_url":"https://avatars.githubusercontent.com/u/49275095?"},"repo":{"id":328697653,"name":"ursacomputing/crossbow","url":"https://api.github.com/repos/ursacomputing/crossbow"},"payload":{"ref":"actions-2045-github-verify-rc-source-csharp-linux-almalinux-8-amd64","ref_type":"branch","master_branch":"master","description":"Extra CI for Apache Arrow","pusher_type":"user"},"public":true,"created_at":"2022-05-09T20:29:23Z","org":{"id":70039053,"login":"ursacomputing","gravatar_id":"","url":"https://api.github.com/orgs/ursacomputing","avatar_url":"https://avatars.githubusercontent.com/u/70039053?"}},{"id":"21696256958","type":"IssueCommentEvent","actor":{"id":13381981,"login":"bigcat88","display_login":"bigcat88","gravatar_id":"","url":"https://api.github.com/users/bigcat88","avatar_url":"https://avatars.githubusercontent.com/u/13381981?"},"repo":{"id":377284839,"name":"andrey18106/mediadc","url":"https://api.github.com/repos/andrey18106/mediadc"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/andrey18106/mediadc/issues/57","repository_url":"https://api.github.com/repos/andrey18106/mediadc","labels_url":"https://api.github.com/repos/andrey18106/mediadc/issues/57/labels{/name}","comments_url":"https://api.github.com/repos/andrey18106/mediadc/issues/57/comments","events_url":"https://api.github.com/repos/andrey18106/mediadc/issues/57/events","html_url":"https://github.com/andrey18106/mediadc/issues/57","id":1218360523,"node_id":"I_kwDOFnzo585InrTL","number":57,"title":"`\'ascii\' codec can\'t encode characters in position 49-50: ordinal not in range(128)`","user":{"login":"emptinessboy","id":25280590,"node_id":"MDQ6VXNlcjI1MjgwNTkw","avatar_url":"https://avatars.githubusercontent.com/u/25280590?v=4","gravatar_id":"","url":"https://api.github.com/users/emptinessboy","html_url":"https://github.com/emptinessboy","followers_url":"https://api.github.com/users/emptinessboy/followers","following_url":"https://api.github.com/users/emptinessboy/following{/other_user}","gists_url":"https://api.github.com/users/emptinessboy/gists{/gist_id}","starred_url":"https://api.github.com/users/emptinessboy/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/emptinessboy/subscriptions","organizations_url":"https://api.github.com/users/emptinessboy/orgs","repos_url":"https://api.github.com/users/emptinessboy/repos","events_url":"https://api.github.com/users/emptinessboy/events{/privacy}","received_events_url":"https://api.github.com/users/emptinessboy/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":8,"created_at":"2022-04-28T08:09:06Z","updated_at":"2022-05-09T20:29:23Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"**Describe the bug**\\r\\nException(UnicodeEncodeError): `\'ascii\' codec can\'t encode characters in position 49-50: ordinal not in range(128)`\\r\\n\\r\\n**To Reproduce**\\r\\nWhen I use a folder contain Chinese characters.\\r\\n\\r\\n**Screenshots**\\r\\n![](https://s3.bmp.ovh/imgs/2022/04/28/dd59381e618d3d7f.png)\\r\\n\\r\\n**Desktop (please complete the following information):**\\r\\n```json\\r\\n{\\r\\n  \\"nextcloud-version\\": \\"23.0.4.1\\",\\r\\n  \\"webserver\\": \\"nginx/1.21.4\\",\\r\\n  \\"database\\": {\\r\\n    \\"type\\": \\"mysql\\",\\r\\n    \\"version\\": \\"8.0.20\\",\\r\\n    \\"size\\": \\"121700352\\"\\r\\n  },\\r\\n  \\"php-version\\": \\"8.0.7\\",\\r\\n  \\"php-interpreter\\": \\"php\\",\\r\\n  \\"python-version\\": \\"3.6.8\\",\\r\\n  \\"python-interpretter-setting\\": \\"/usr/bin/python3\\",\\r\\n  \\"os\\": \\"Linux\\",\\r\\n  \\"os-release\\": \\"5.17.4-1.el7.elrepo.x86_64\\",\\r\\n  \\"machine-type\\": \\"x86_64\\",\\r\\n  \\"mediadc-version\\": \\"0.1.9\\" ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 09 May 2022 20:34:23 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"cda3639d41accb04e85de4be2be2fe3cbcbff745970cc418b247470440cb5298"', 'Last-Modified': 'Mon, 09 May 2022 20:29:23 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1652132063', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'D9DA:65F8:260F62:6440A4:62797ACF'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '21696256953',
#   'type': 'CreateEvent',
#   'actor': {'id': 49275095,
#    'login': 'ursabot',
#    'display_login': 'ursabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ursabot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49275095?'},
#   'repo': {'id': 328697653,
#    'name': 'ursacomputing/crossbow',
#    'url': 'https://api.github.com/repos/ursacomputing/crossbow'},
#   'payload': {'ref': 'actions-2045-github-verify-rc-source-csharp-linux-almalinux-8-amd64',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Extra CI for Apache Arrow',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z',
#   'org': {'id': 70039053,
#    'login': 'ursacomputing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ursacomputing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70039053?'}},
#  {'id': '21696256958',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 13381981,
#    'login': 'bigcat88',
#    'display_login': 'bigcat88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bigcat88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13381981?'},
#   'repo': {'id': 377284839,
#    'name': 'andrey18106/mediadc',
#    'url': 'https://api.github.com/repos/andrey18106/mediadc'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57',
#     'repository_url': 'https://api.github.com/repos/andrey18106/mediadc',
#     'labels_url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57/comments',
#     'events_url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57/events',
#     'html_url': 'https://github.com/andrey18106/mediadc/issues/57',
#     'id': 1218360523,
#     'node_id': 'I_kwDOFnzo585InrTL',
#     'number': 57,
#     'title': "`'ascii' codec can't encode characters in position 49-50: ordinal not in range(128)`",
#     'user': {'login': 'emptinessboy',
#      'id': 25280590,
#      'node_id': 'MDQ6VXNlcjI1MjgwNTkw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/25280590?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/emptinessboy',
#      'html_url': 'https://github.com/emptinessboy',
#      'followers_url': 'https://api.github.com/users/emptinessboy/followers',
#      'following_url': 'https://api.github.com/users/emptinessboy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/emptinessboy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/emptinessboy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/emptinessboy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/emptinessboy/orgs',
#      'repos_url': 'https://api.github.com/users/emptinessboy/repos',
#      'events_url': 'https://api.github.com/users/emptinessboy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/emptinessboy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2022-04-28T08:09:06Z',
#     'updated_at': '2022-05-09T20:29:23Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '**Describe the bug**\r\nException(UnicodeEncodeError): `\'ascii\' codec can\'t encode characters in position 49-50: ordinal not in range(128)`\r\n\r\n**To Reproduce**\r\nWhen I use a folder contain Chinese characters.\r\n\r\n**Screenshots**\r\n![](https://s3.bmp.ovh/imgs/2022/04/28/dd59381e618d3d7f.png)\r\n\r\n**Desktop (please complete the following information):**\r\n```json\r\n{\r\n  "nextcloud-version": "23.0.4.1",\r\n  "webserver": "nginx/1.21.4",\r\n  "database": {\r\n    "type": "mysql",\r\n    "version": "8.0.20",\r\n    "size": "121700352"\r\n  },\r\n  "php-version": "8.0.7",\r\n  "php-interpreter": "php",\r\n  "python-version": "3.6.8",\r\n  "python-interpretter-setting": "/usr/bin/python3",\r\n  "os": "Linux",\r\n  "os-release": "5.17.4-1.el7.elrepo.x86_64",\r\n  "machine-type": "x86_64",\r\n  "mediadc-version": "0.1.9",\r\n  "mediadc-settings": {\r\n    "remote_filesize_limit": "536870912",\r\n    "installed": {\r\n      "status": true,\r\n      "installed_list": {\r\n        "boost": {\r\n          "hexhamming": {\r\n            "package": "hexhamming",\r\n            "version": "2.2.3",\r\n            "location": "global"\r\n          }\r\n        },\r\n        "optional": {\r\n          "nacl": {\r\n            "package": "pynacl",\r\n            "version": "1.5.0",\r\n            "location": "global"\r\n          },\r\n          "pywt": {\r\n            "package": "pywavelets",\r\n            "version": "1.1.1",\r\n            "location": "global"\r\n          },\r\n          "scipy": {\r\n            "package": "scipy",\r\n            "version": "1.5.4",\r\n            "location": "global"\r\n          },\r\n          "pillow_heif": {\r\n            "package": "pillow_heif",\r\n            "version": "0.2.2",\r\n            "location": "global"\r\n          },\r\n          "cryptography": {\r\n            "package": "cryptography",\r\n            "version": "37.0.0",\r\n            "location": "global"\r\n          }\r\n        },\r\n        "required": {\r\n          "PIL": {\r\n            "package": "pillow",\r\n            "version": "8.4.0",\r\n            "location": "global"\r\n          },\r\n          "numpy": {\r\n            "package": "numpy",\r\n            "version": "1.19.5",\r\n            "location": "global"\r\n          }\r\n        }\r\n      },\r\n      "video_required": [],\r\n      "not_installed_list": {\r\n        "boost": [],\r\n        "optional": [],\r\n        "required": []\r\n      },\r\n      "available_algorithms": [\r\n        "average",\r\n        "dhash",\r\n        "phash",\r\n        "whash"\r\n      ]\r\n    }\r\n  }\r\n}\r\n```\r\n\r\n**Additional context**\r\nlocate on my system\r\n```\r\n[root@xf ~]# locale\r\nLANG=zh_CN.UTF-8\r\nLC_CTYPE="zh_CN.UTF-8"\r\nLC_NUMERIC="zh_CN.UTF-8"\r\nLC_TIME="zh_CN.UTF-8"\r\nLC_COLLATE="zh_CN.UTF-8"\r\nLC_MONETARY="zh_CN.UTF-8"\r\nLC_MESSAGES="zh_CN.UTF-8"\r\nLC_PAPER="zh_CN.UTF-8"\r\nLC_NAME="zh_CN.UTF-8"\r\nLC_ADDRESS="zh_CN.UTF-8"\r\nLC_TELEPHONE="zh_CN.UTF-8"\r\nLC_MEASUREMENT="zh_CN.UTF-8"\r\nLC_IDENTIFICATION="zh_CN.UTF-8"\r\nLC_ALL=\r\n```\r\n\r\nI also tried export LC_ALL="en_US.utf8" , but not work.\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/andrey18106/mediadc/issues/comments/1121546838',
#     'html_url': 'https://github.com/andrey18106/mediadc/issues/57#issuecomment-1121546838',
#     'issue_url': 'https://api.github.com/repos/andrey18106/mediadc/issues/57',
#     'id': 1121546838,
#     'node_id': 'IC_kwDOFnzo585C2XJW',
#     'user': {'login': 'bigcat88',
#      'id': 13381981,
#      'node_id': 'MDQ6VXNlcjEzMzgxOTgx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13381981?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bigcat88',
#      'html_url': 'https://github.com/bigcat88',
#      'followers_url': 'https://api.github.com/users/bigcat88/followers',
#      'following_url': 'https://api.github.com/users/bigcat88/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bigcat88/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bigcat88/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bigcat88/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bigcat88/orgs',
#      'repos_url': 'https://api.github.com/users/bigcat88/repos',
#      'events_url': 'https://api.github.com/users/bigcat88/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bigcat88/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-05-09T20:29:23Z',
#     'updated_at': '2022-05-09T20:29:23Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Soon will be a newer version posted, maybe there will be no this bug(but maybe will be still)\r\nIf new version will still not work, is there any chances to test-run it on a newer version of python? Like 3.7-3.8 ? ',
#     'reactions': {'url': 'https://api.github.com/repos/andrey18106/mediadc/issues/comments/1121546838/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256972',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 365115914,
#    'name': 'jaoafa/Javajaotan2',
#    'url': 'https://api.github.com/repos/jaoafa/Javajaotan2'},
#   'payload': {'ref': 'renovate/ch.qos.logback-logback-classic-1.x',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'jao Minecraft Server Official Discord Bot v2',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z',
#   'org': {'id': 23239586,
#    'login': 'jaoafa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/jaoafa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23239586?'}},
#  {'id': '21696256952',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 468831617,
#    'name': 'hmans/controlfreak',
#    'url': 'https://api.github.com/repos/hmans/controlfreak'},
#   'payload': {'action': 'opened',
#    'number': 31,
#    'pull_request': {'url': 'https://api.github.com/repos/hmans/controlfreak/pulls/31',
#     'id': 931616862,
#     'node_id': 'PR_kwDOG_HNgc43h1he',
#     'html_url': 'https://github.com/hmans/controlfreak/pull/31',
#     'diff_url': 'https://github.com/hmans/controlfreak/pull/31.diff',
#     'patch_url': 'https://github.com/hmans/controlfreak/pull/31.patch',
#     'issue_url': 'https://api.github.com/repos/hmans/controlfreak/issues/31',
#     'number': 31,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @react-three/fiber from 8.0.11 to 8.0.13',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@react-three/fiber](https://github.com/pmndrs/react-three-fiber) from 8.0.11 to 8.0.13.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/pmndrs/react-three-fiber/commits">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@react-three/fiber&package-manager=npm_and_yarn&previous-version=8.0.11&new-version=8.0.13)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'created_at': '2022-05-09T20:29:23Z',
#     'updated_at': '2022-05-09T20:29:23Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/hmans/controlfreak/pulls/31/commits',
#     'review_comments_url': 'https://api.github.com/repos/hmans/controlfreak/pulls/31/comments',
#     'review_comment_url': 'https://api.github.com/repos/hmans/controlfreak/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/hmans/controlfreak/issues/31/comments',
#     'statuses_url': 'https://api.github.com/repos/hmans/controlfreak/statuses/331f92c6d0efc000f0cdcdb602cd8476e178fa44',
#     'head': {'label': 'hmans:dependabot/npm_and_yarn/react-three/fiber-8.0.13',
#      'ref': 'dependabot/npm_and_yarn/react-three/fiber-8.0.13',
#      'sha': '331f92c6d0efc000f0cdcdb602cd8476e178fa44',
#      'user': {'login': 'hmans',
#       'id': 1061,
#       'node_id': 'MDQ6VXNlcjEwNjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1061?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/hmans',
#       'html_url': 'https://github.com/hmans',
#       'followers_url': 'https://api.github.com/users/hmans/followers',
#       'following_url': 'https://api.github.com/users/hmans/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hmans/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/hmans/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hmans/subscriptions',
#       'organizations_url': 'https://api.github.com/users/hmans/orgs',
#       'repos_url': 'https://api.github.com/users/hmans/repos',
#       'events_url': 'https://api.github.com/users/hmans/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/hmans/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 468831617,
#       'node_id': 'R_kgDOG_HNgQ',
#       'name': 'controlfreak',
#       'full_name': 'hmans/controlfreak',
#       'private': False,
#       'owner': {'login': 'hmans',
#        'id': 1061,
#        'node_id': 'MDQ6VXNlcjEwNjE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1061?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/hmans',
#        'html_url': 'https://github.com/hmans',
#        'followers_url': 'https://api.github.com/users/hmans/followers',
#        'following_url': 'https://api.github.com/users/hmans/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/hmans/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/hmans/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/hmans/subscriptions',
#        'organizations_url': 'https://api.github.com/users/hmans/orgs',
#        'repos_url': 'https://api.github.com/users/hmans/repos',
#        'events_url': 'https://api.github.com/users/hmans/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/hmans/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/hmans/controlfreak',
#       'description': 'Composable Game Input.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/hmans/controlfreak',
#       'forks_url': 'https://api.github.com/repos/hmans/controlfreak/forks',
#       'keys_url': 'https://api.github.com/repos/hmans/controlfreak/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/hmans/controlfreak/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/hmans/controlfreak/teams',
#       'hooks_url': 'https://api.github.com/repos/hmans/controlfreak/hooks',
#       'issue_events_url': 'https://api.github.com/repos/hmans/controlfreak/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/hmans/controlfreak/events',
#       'assignees_url': 'https://api.github.com/repos/hmans/controlfreak/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/hmans/controlfreak/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/hmans/controlfreak/tags',
#       'blobs_url': 'https://api.github.com/repos/hmans/controlfreak/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/hmans/controlfreak/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/hmans/controlfreak/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/hmans/controlfreak/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/hmans/controlfreak/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/hmans/controlfreak/languages',
#       'stargazers_url': 'https://api.github.com/repos/hmans/controlfreak/stargazers',
#       'contributors_url': 'https://api.github.com/repos/hmans/controlfreak/contributors',
#       'subscribers_url': 'https://api.github.com/repos/hmans/controlfreak/subscribers',
#       'subscription_url': 'https://api.github.com/repos/hmans/controlfreak/subscription',
#       'commits_url': 'https://api.github.com/repos/hmans/controlfreak/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/hmans/controlfreak/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/hmans/controlfreak/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/hmans/controlfreak/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/hmans/controlfreak/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/hmans/controlfreak/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/hmans/controlfreak/merges',
#       'archive_url': 'https://api.github.com/repos/hmans/controlfreak/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/hmans/controlfreak/downloads',
#       'issues_url': 'https://api.github.com/repos/hmans/controlfreak/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/hmans/controlfreak/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/hmans/controlfreak/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/hmans/controlfreak/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/hmans/controlfreak/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/hmans/controlfreak/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/hmans/controlfreak/deployments',
#       'created_at': '2022-03-11T16:54:27Z',
#       'updated_at': '2022-04-28T13:23:50Z',
#       'pushed_at': '2022-05-09T20:29:22Z',
#       'git_url': 'git://github.com/hmans/controlfreak.git',
#       'ssh_url': 'git@github.com:hmans/controlfreak.git',
#       'clone_url': 'https://github.com/hmans/controlfreak.git',
#       'svn_url': 'https://github.com/hmans/controlfreak',
#       'homepage': None,
#       'size': 685,
#       'stargazers_count': 22,
#       'watchers_count': 22,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 10,
#       'watchers': 22,
#       'default_branch': 'main'}},
#     'base': {'label': 'hmans:main',
#      'ref': 'main',
#      'sha': '5f7dc160b0bba44941a9a4310c1f45e5cff3426a',
#      'user': {'login': 'hmans',
#       'id': 1061,
#       'node_id': 'MDQ6VXNlcjEwNjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1061?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/hmans',
#       'html_url': 'https://github.com/hmans',
#       'followers_url': 'https://api.github.com/users/hmans/followers',
#       'following_url': 'https://api.github.com/users/hmans/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hmans/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/hmans/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hmans/subscriptions',
#       'organizations_url': 'https://api.github.com/users/hmans/orgs',
#       'repos_url': 'https://api.github.com/users/hmans/repos',
#       'events_url': 'https://api.github.com/users/hmans/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/hmans/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 468831617,
#       'node_id': 'R_kgDOG_HNgQ',
#       'name': 'controlfreak',
#       'full_name': 'hmans/controlfreak',
#       'private': False,
#       'owner': {'login': 'hmans',
#        'id': 1061,
#        'node_id': 'MDQ6VXNlcjEwNjE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1061?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/hmans',
#        'html_url': 'https://github.com/hmans',
#        'followers_url': 'https://api.github.com/users/hmans/followers',
#        'following_url': 'https://api.github.com/users/hmans/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/hmans/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/hmans/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/hmans/subscriptions',
#        'organizations_url': 'https://api.github.com/users/hmans/orgs',
#        'repos_url': 'https://api.github.com/users/hmans/repos',
#        'events_url': 'https://api.github.com/users/hmans/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/hmans/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/hmans/controlfreak',
#       'description': 'Composable Game Input.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/hmans/controlfreak',
#       'forks_url': 'https://api.github.com/repos/hmans/controlfreak/forks',
#       'keys_url': 'https://api.github.com/repos/hmans/controlfreak/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/hmans/controlfreak/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/hmans/controlfreak/teams',
#       'hooks_url': 'https://api.github.com/repos/hmans/controlfreak/hooks',
#       'issue_events_url': 'https://api.github.com/repos/hmans/controlfreak/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/hmans/controlfreak/events',
#       'assignees_url': 'https://api.github.com/repos/hmans/controlfreak/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/hmans/controlfreak/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/hmans/controlfreak/tags',
#       'blobs_url': 'https://api.github.com/repos/hmans/controlfreak/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/hmans/controlfreak/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/hmans/controlfreak/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/hmans/controlfreak/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/hmans/controlfreak/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/hmans/controlfreak/languages',
#       'stargazers_url': 'https://api.github.com/repos/hmans/controlfreak/stargazers',
#       'contributors_url': 'https://api.github.com/repos/hmans/controlfreak/contributors',
#       'subscribers_url': 'https://api.github.com/repos/hmans/controlfreak/subscribers',
#       'subscription_url': 'https://api.github.com/repos/hmans/controlfreak/subscription',
#       'commits_url': 'https://api.github.com/repos/hmans/controlfreak/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/hmans/controlfreak/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/hmans/controlfreak/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/hmans/controlfreak/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/hmans/controlfreak/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/hmans/controlfreak/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/hmans/controlfreak/merges',
#       'archive_url': 'https://api.github.com/repos/hmans/controlfreak/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/hmans/controlfreak/downloads',
#       'issues_url': 'https://api.github.com/repos/hmans/controlfreak/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/hmans/controlfreak/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/hmans/controlfreak/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/hmans/controlfreak/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/hmans/controlfreak/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/hmans/controlfreak/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/hmans/controlfreak/deployments',
#       'created_at': '2022-03-11T16:54:27Z',
#       'updated_at': '2022-04-28T13:23:50Z',
#       'pushed_at': '2022-05-09T20:29:22Z',
#       'git_url': 'git://github.com/hmans/controlfreak.git',
#       'ssh_url': 'git@github.com:hmans/controlfreak.git',
#       'clone_url': 'https://github.com/hmans/controlfreak.git',
#       'svn_url': 'https://github.com/hmans/controlfreak',
#       'homepage': None,
#       'size': 685,
#       'stargazers_count': 22,
#       'watchers_count': 22,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 10,
#       'watchers': 22,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/hmans/controlfreak/pulls/31'},
#      'html': {'href': 'https://github.com/hmans/controlfreak/pull/31'},
#      'issue': {'href': 'https://api.github.com/repos/hmans/controlfreak/issues/31'},
#      'comments': {'href': 'https://api.github.com/repos/hmans/controlfreak/issues/31/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/hmans/controlfreak/pulls/31/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/hmans/controlfreak/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/hmans/controlfreak/pulls/31/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/hmans/controlfreak/statuses/331f92c6d0efc000f0cdcdb602cd8476e178fa44'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 11,
#     'deletions': 18,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256957',
#   'type': 'CreateEvent',
#   'actor': {'id': 105082361,
#    'login': 'irbradshaw',
#    'display_login': 'irbradshaw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/irbradshaw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105082361?'},
#   'repo': {'id': 490434943,
#    'name': 'irbradshaw/irbradshaw',
#    'url': 'https://api.github.com/repos/irbradshaw/irbradshaw'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Config files for my GitHub profile.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256959',
#   'type': 'PushEvent',
#   'actor': {'id': 37708374,
#    'login': 'artstar10',
#    'display_login': 'artstar10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/artstar10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37708374?'},
#   'repo': {'id': 490310621,
#    'name': 'artstar10/udemy',
#    'url': 'https://api.github.com/repos/artstar10/udemy'},
#   'payload': {'push_id': 9835999511,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'd22b76a0d655f8f961a2081d274266363afc1ff8',
#    'before': 'a69ccb6addb4757159db8a1794d8919f326a27bb',
#    'commits': [{'sha': '5b69fc260573601dbd21440b047578f178f49eda',
#      'author': {'email': 'arthurnevesx@hotmail.com', 'name': 'Artstar10'},
#      'message': 'atualizando: estrutura básica back-end',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/artstar10/udemy/commits/5b69fc260573601dbd21440b047578f178f49eda'},
#     {'sha': 'd22b76a0d655f8f961a2081d274266363afc1ff8',
#      'author': {'email': 'arthurnevesx@hotmail.com', 'name': 'Artstar10'},
#      'message': 'atualizando: criando o frontend do chat',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/artstar10/udemy/commits/d22b76a0d655f8f961a2081d274266363afc1ff8'}]},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256938',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 7353419,
#    'login': 'rickclephas',
#    'display_login': 'rickclephas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rickclephas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7353419?'},
#   'repo': {'id': 3432266,
#    'name': 'JetBrains/kotlin',
#    'url': 'https://api.github.com/repos/JetBrains/kotlin'},
#   'payload': {'action': 'opened',
#    'number': 4818,
#    'pull_request': {'url': 'https://api.github.com/repos/JetBrains/kotlin/pulls/4818',
#     'id': 931616856,
#     'node_id': 'PR_kwDOADRfSs43h1hY',
#     'html_url': 'https://github.com/JetBrains/kotlin/pull/4818',
#     'diff_url': 'https://github.com/JetBrains/kotlin/pull/4818.diff',
#     'patch_url': 'https://github.com/JetBrains/kotlin/pull/4818.patch',
#     'issue_url': 'https://api.github.com/repos/JetBrains/kotlin/issues/4818',
#     'number': 4818,
#     'state': 'open',
#     'locked': False,
#     'title': 'ObjCRefined and SwiftRefined annotations',
#     'user': {'login': 'rickclephas',
#      'id': 7353419,
#      'node_id': 'MDQ6VXNlcjczNTM0MTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7353419?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rickclephas',
#      'html_url': 'https://github.com/rickclephas',
#      'followers_url': 'https://api.github.com/users/rickclephas/followers',
#      'following_url': 'https://api.github.com/users/rickclephas/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rickclephas/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rickclephas/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rickclephas/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rickclephas/orgs',
#      'repos_url': 'https://api.github.com/users/rickclephas/repos',
#      'events_url': 'https://api.github.com/users/rickclephas/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rickclephas/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Relates to [KT-42297](https://youtrack.jetbrains.com/issue/KT-42297).\r\n\r\nThe Kotlin ObjC/Swift is pretty great, but at the moment there are also some gabs (especially with the Swift interop) like suspend functions and enum classes.\r\nWith some boilerplate code the interop for such code can be improved, which can even be automated with a compiler plugin/annotation processor.\r\nHowever one limitation of such boilerplate code is that it adds unnecessary declarations to your public API.\r\n\r\nWith the `ObjCRefined` and `SwiftRefined` annotations we can hide these unnecessary declarations from the public API.\r\nBoth annotations can be used as meta-annotations such that annotation processors can generate ObjC/Swift friendly APIs while automatically hiding the original declaration.\r\n\r\n### ObjCRefined\r\nFunctions and properties annotated with the `ObjCRefined` annotation won\'t be exported to ObjC.\r\nThis allows you to create a more ObjC friendly version in your Kotlin.\r\n\r\n> With the `ObjCName` annotation from #4815 you could even use the original name of the function/property for your ObjC friendly version.\r\n\r\n### SwiftRefined\r\nThe `SwiftRefined` annotation adds the [`swift_private`](https://developer.apple.com/documentation/swift/objective-c_and_c_code_customization/improving_objective-c_api_declarations_for_swift) attribute to the declaration.\r\nThis results in the declarations being prefixed with `__`, which make them "invisible" from Swift.\r\nThese declarations can still be used in your Swift code to create your Swift friendly API, but won\'t be shown in e.g. the Xcode autocomplete.\r\n\r\n### ToDos\r\n\r\n- [ ] Add tests\r\n- [ ] Add documentation\r\n',
#     'created_at': '2022-05-09T20:29:22Z',
#     'updated_at': '2022-05-09T20:29:22Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/JetBrains/kotlin/pulls/4818/commits',
#     'review_comments_url': 'https://api.github.com/repos/JetBrains/kotlin/pulls/4818/comments',
#     'review_comment_url': 'https://api.github.com/repos/JetBrains/kotlin/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/JetBrains/kotlin/issues/4818/comments',
#     'statuses_url': 'https://api.github.com/repos/JetBrains/kotlin/statuses/39ce28a10d2be046128fa429e453261af7066866',
#     'head': {'label': 'rickclephas:feature/objc-swift-refined',
#      'ref': 'feature/objc-swift-refined',
#      'sha': '39ce28a10d2be046128fa429e453261af7066866',
#      'user': {'login': 'rickclephas',
#       'id': 7353419,
#       'node_id': 'MDQ6VXNlcjczNTM0MTk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7353419?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rickclephas',
#       'html_url': 'https://github.com/rickclephas',
#       'followers_url': 'https://api.github.com/users/rickclephas/followers',
#       'following_url': 'https://api.github.com/users/rickclephas/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rickclephas/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rickclephas/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rickclephas/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rickclephas/orgs',
#       'repos_url': 'https://api.github.com/users/rickclephas/repos',
#       'events_url': 'https://api.github.com/users/rickclephas/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rickclephas/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 437392107,
#       'node_id': 'R_kgDOGhIS6w',
#       'name': 'kotlin',
#       'full_name': 'rickclephas/kotlin',
#       'private': False,
#       'owner': {'login': 'rickclephas',
#        'id': 7353419,
#        'node_id': 'MDQ6VXNlcjczNTM0MTk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7353419?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rickclephas',
#        'html_url': 'https://github.com/rickclephas',
#        'followers_url': 'https://api.github.com/users/rickclephas/followers',
#        'following_url': 'https://api.github.com/users/rickclephas/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rickclephas/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rickclephas/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rickclephas/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rickclephas/orgs',
#        'repos_url': 'https://api.github.com/users/rickclephas/repos',
#        'events_url': 'https://api.github.com/users/rickclephas/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rickclephas/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/rickclephas/kotlin',
#       'description': 'The Kotlin Programming Language. ',
#       'fork': True,
#       'url': 'https://api.github.com/repos/rickclephas/kotlin',
#       'forks_url': 'https://api.github.com/repos/rickclephas/kotlin/forks',
#       'keys_url': 'https://api.github.com/repos/rickclephas/kotlin/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rickclephas/kotlin/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rickclephas/kotlin/teams',
#       'hooks_url': 'https://api.github.com/repos/rickclephas/kotlin/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rickclephas/kotlin/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rickclephas/kotlin/events',
#       'assignees_url': 'https://api.github.com/repos/rickclephas/kotlin/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rickclephas/kotlin/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rickclephas/kotlin/tags',
#       'blobs_url': 'https://api.github.com/repos/rickclephas/kotlin/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rickclephas/kotlin/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rickclephas/kotlin/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rickclephas/kotlin/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rickclephas/kotlin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rickclephas/kotlin/languages',
#       'stargazers_url': 'https://api.github.com/repos/rickclephas/kotlin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rickclephas/kotlin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rickclephas/kotlin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rickclephas/kotlin/subscription',
#       'commits_url': 'https://api.github.com/repos/rickclephas/kotlin/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rickclephas/kotlin/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rickclephas/kotlin/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rickclephas/kotlin/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rickclephas/kotlin/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rickclephas/kotlin/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rickclephas/kotlin/merges',
#       'archive_url': 'https://api.github.com/repos/rickclephas/kotlin/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rickclephas/kotlin/downloads',
#       'issues_url': 'https://api.github.com/repos/rickclephas/kotlin/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rickclephas/kotlin/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rickclephas/kotlin/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rickclephas/kotlin/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rickclephas/kotlin/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rickclephas/kotlin/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rickclephas/kotlin/deployments',
#       'created_at': '2021-12-11T21:25:55Z',
#       'updated_at': '2021-12-26T19:09:32Z',
#       'pushed_at': '2022-05-09T19:13:21Z',
#       'git_url': 'git://github.com/rickclephas/kotlin.git',
#       'ssh_url': 'git@github.com:rickclephas/kotlin.git',
#       'clone_url': 'https://github.com/rickclephas/kotlin.git',
#       'svn_url': 'https://github.com/rickclephas/kotlin',
#       'homepage': 'https://kotlinlang.org',
#       'size': 1411723,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Kotlin',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'JetBrains:master',
#      'ref': 'master',
#      'sha': '9f31f074da71487315bbb6a55207db23feca7278',
#      'user': {'login': 'JetBrains',
#       'id': 878437,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg3ODQzNw==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/878437?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/JetBrains',
#       'html_url': 'https://github.com/JetBrains',
#       'followers_url': 'https://api.github.com/users/JetBrains/followers',
#       'following_url': 'https://api.github.com/users/JetBrains/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/JetBrains/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/JetBrains/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/JetBrains/subscriptions',
#       'organizations_url': 'https://api.github.com/users/JetBrains/orgs',
#       'repos_url': 'https://api.github.com/users/JetBrains/repos',
#       'events_url': 'https://api.github.com/users/JetBrains/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/JetBrains/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 3432266,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDMyMjY2',
#       'name': 'kotlin',
#       'full_name': 'JetBrains/kotlin',
#       'private': False,
#       'owner': {'login': 'JetBrains',
#        'id': 878437,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg3ODQzNw==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/878437?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/JetBrains',
#        'html_url': 'https://github.com/JetBrains',
#        'followers_url': 'https://api.github.com/users/JetBrains/followers',
#        'following_url': 'https://api.github.com/users/JetBrains/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/JetBrains/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/JetBrains/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/JetBrains/subscriptions',
#        'organizations_url': 'https://api.github.com/users/JetBrains/orgs',
#        'repos_url': 'https://api.github.com/users/JetBrains/repos',
#        'events_url': 'https://api.github.com/users/JetBrains/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/JetBrains/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/JetBrains/kotlin',
#       'description': 'The Kotlin Programming Language. ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/JetBrains/kotlin',
#       'forks_url': 'https://api.github.com/repos/JetBrains/kotlin/forks',
#       'keys_url': 'https://api.github.com/repos/JetBrains/kotlin/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/JetBrains/kotlin/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/JetBrains/kotlin/teams',
#       'hooks_url': 'https://api.github.com/repos/JetBrains/kotlin/hooks',
#       'issue_events_url': 'https://api.github.com/repos/JetBrains/kotlin/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/JetBrains/kotlin/events',
#       'assignees_url': 'https://api.github.com/repos/JetBrains/kotlin/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/JetBrains/kotlin/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/JetBrains/kotlin/tags',
#       'blobs_url': 'https://api.github.com/repos/JetBrains/kotlin/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/JetBrains/kotlin/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/JetBrains/kotlin/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/JetBrains/kotlin/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/JetBrains/kotlin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/JetBrains/kotlin/languages',
#       'stargazers_url': 'https://api.github.com/repos/JetBrains/kotlin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/JetBrains/kotlin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/JetBrains/kotlin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/JetBrains/kotlin/subscription',
# ...
#       'subscription_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/subscription',
#       'commits_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/merges',
#       'archive_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/downloads',
#       'issues_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/deployments',
#       'created_at': '2022-02-25T11:52:51Z',
#       'updated_at': '2022-02-25T11:52:51Z',
#       'pushed_at': '2022-05-09T20:26:54Z',
#       'git_url': 'git://github.com/varsha84/hyf-dotnet-masterclass.git',
#       'ssh_url': 'git@github.com:varsha84/hyf-dotnet-masterclass.git',
#       'clone_url': 'https://github.com/varsha84/hyf-dotnet-masterclass.git',
#       'svn_url': 'https://github.com/varsha84/hyf-dotnet-masterclass',
#       'homepage': None,
#       'size': 909,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'varsha84:main',
#      'ref': 'main',
#      'sha': '97d02ba226e4fa60549b0deabb6b77fc81e968a5',
#      'user': {'login': 'varsha84',
#       'id': 59140479,
#       'node_id': 'MDQ6VXNlcjU5MTQwNDc5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/59140479?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/varsha84',
#       'html_url': 'https://github.com/varsha84',
#       'followers_url': 'https://api.github.com/users/varsha84/followers',
#       'following_url': 'https://api.github.com/users/varsha84/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/varsha84/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/varsha84/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/varsha84/subscriptions',
#       'organizations_url': 'https://api.github.com/users/varsha84/orgs',
#       'repos_url': 'https://api.github.com/users/varsha84/repos',
#       'events_url': 'https://api.github.com/users/varsha84/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/varsha84/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 463514059,
#       'node_id': 'R_kgDOG6Cpyw',
#       'name': 'hyf-dotnet-masterclass',
#       'full_name': 'varsha84/hyf-dotnet-masterclass',
#       'private': False,
#       'owner': {'login': 'varsha84',
#        'id': 59140479,
#        'node_id': 'MDQ6VXNlcjU5MTQwNDc5',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/59140479?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/varsha84',
#        'html_url': 'https://github.com/varsha84',
#        'followers_url': 'https://api.github.com/users/varsha84/followers',
#        'following_url': 'https://api.github.com/users/varsha84/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/varsha84/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/varsha84/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/varsha84/subscriptions',
#        'organizations_url': 'https://api.github.com/users/varsha84/orgs',
#        'repos_url': 'https://api.github.com/users/varsha84/repos',
#        'events_url': 'https://api.github.com/users/varsha84/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/varsha84/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/varsha84/hyf-dotnet-masterclass',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass',
#       'forks_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/forks',
#       'keys_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/teams',
#       'hooks_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/hooks',
#       'issue_events_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/events',
#       'assignees_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/tags',
#       'blobs_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/languages',
#       'stargazers_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/stargazers',
#       'contributors_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/contributors',
#       'subscribers_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/subscribers',
#       'subscription_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/subscription',
#       'commits_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/merges',
#       'archive_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/downloads',
#       'issues_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/deployments',
#       'created_at': '2022-02-25T11:52:51Z',
#       'updated_at': '2022-02-25T11:52:51Z',
#       'pushed_at': '2022-05-09T20:26:54Z',
#       'git_url': 'git://github.com/varsha84/hyf-dotnet-masterclass.git',
#       'ssh_url': 'git@github.com:varsha84/hyf-dotnet-masterclass.git',
#       'clone_url': 'https://github.com/varsha84/hyf-dotnet-masterclass.git',
#       'svn_url': 'https://github.com/varsha84/hyf-dotnet-masterclass',
#       'homepage': None,
#       'size': 909,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls/8'},
#      'html': {'href': 'https://github.com/varsha84/hyf-dotnet-masterclass/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/varsha84/hyf-dotnet-masterclass/statuses/ca52450c2f18e4da61143190fbc1946d0585e18e'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 9336,
#     'deletions': 0,
#     'changed_files': 67}},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256834',
#   'type': 'PushEvent',
#   'actor': {'id': 22228242,
#    'login': 'greghell',
#    'display_login': 'greghell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greghell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22228242?'},
#   'repo': {'id': 461082126,
#    'name': 'greghell/LWASNAP',
#    'url': 'https://api.github.com/repos/greghell/LWASNAP'},
#   'payload': {'push_id': 9835999439,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6a012f96b5ffe8d5002724224973cba56450d2f4',
#    'before': 'dd5baebbcbc852ad2630ed11d1a913d4a07e87e2',
#    'commits': [{'sha': '6a012f96b5ffe8d5002724224973cba56450d2f4',
#      'author': {'email': 'greg.hellbourg@gmail.com', 'name': 'greghell'},
#      'message': 'Automated update 2022-05-09 13:29:20.248020',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/greghell/LWASNAP/commits/6a012f96b5ffe8d5002724224973cba56450d2f4'}]},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z'},
#  {'id': '21696256832',
#   'type': 'IssuesEvent',
#   'actor': {'id': 89739,
#    'login': 'jxy',
#    'display_login': 'jxy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jxy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89739?'},
#   'repo': {'id': 1300564,
#    'name': 'lattice/quda',
#    'url': 'https://api.github.com/repos/lattice/quda'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/lattice/quda/issues/1274',
#     'repository_url': 'https://api.github.com/repos/lattice/quda',
#     'labels_url': 'https://api.github.com/repos/lattice/quda/issues/1274/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/lattice/quda/issues/1274/comments',
#     'events_url': 'https://api.github.com/repos/lattice/quda/issues/1274/events',
#     'html_url': 'https://github.com/lattice/quda/issues/1274',
#     'id': 1230218852,
#     'node_id': 'I_kwDOABPYVM5JU6Zk',
#     'number': 1274,
#     'title': 'installed executables have RUNPATH pointing to nonexistent directories',
#     'user': {'login': 'jxy',
#      'id': 89739,
#      'node_id': 'MDQ6VXNlcjg5NzM5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/89739?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jxy',
#      'html_url': 'https://github.com/jxy',
#      'followers_url': 'https://api.github.com/users/jxy/followers',
#      'following_url': 'https://api.github.com/users/jxy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jxy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jxy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jxy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jxy/orgs',
#      'repos_url': 'https://api.github.com/users/jxy/repos',
#      'events_url': 'https://api.github.com/users/jxy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jxy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-05-09T20:29:22Z',
#     'updated_at': '2022-05-09T20:29:22Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'With `QUDA_DOWNLOAD_USQCD`, `make install` installs things under `usqcd` by default, and we have `usqcd/bin`, `usqcd/lib`, and `usqcd/include`.  However, the `RUNPATH` of installed binaries, eg. from `readelf -d usqcd/bin/blas_test`, points to `usqcd/lib64`, which does not exist.  As a result, directly running `tests/blas_test` after build works fine, but `make install` creates executables that have the wrong RPATH and cannot run without changing the environment or its RPATH.',
#     'reactions': {'url': 'https://api.github.com/repos/lattice/quda/issues/1274/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/lattice/quda/issues/1274/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-05-09T20:29:23Z',
#   'org': {'id': 573845,
#    'login': 'lattice',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lattice',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/573845?'}}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = None

# %%
# How does that need to adapt for charmander?
char_url = None

# %%
# Check the status code, will this work?

# %%
# Now let's actually get the response
char_resp = None

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-a2d51b0d5ce9> in <module>
#       1 # Let's check out some details about the response
# ----> 2 char_resp.keys()
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
char_resp['id']

# %%
char_resp['name']

# %%
char_resp['types']

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    pass

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!

    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_api_key

tmdb_key_2 = tmdb_api_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()

# %%
# How many similar movies did it find?
similar_resp['total_results']

# %%
# but is that the length of these results?
len(similar_resp['results'])

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
